# %% [markdown]
# # Threshold Tuning and Saving to Pickle File

# %% [markdown]
# In this notebook we will perfrom threshold tuning and save our model to a pickle file.

# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading-In Training Data

# %%
df_default = pd.read_csv("data_processed/01_binary_training.csv", low_memory=False)
df_default.head().T
# Out:
#                                                 0                   1
# funded_amnt                               30000.0              7850.0  \
# addr_state                                     IL                  IN
# annual_inc                                70000.0             95000.0
# application_type                       Individual          Individual
# dti                                         22.78               13.97
# earliest_cr_line                         Apr-1996            Apr-1990
# emp_length                               < 1 year             4 years
# emp_title              Surgical Clinical Reviewer          Technician
# fico_range_high                             729.0               679.0
# fico_range_low                              725.0               675.0
# grade                                           A                   C
# home_ownership                               RENT            MORTGAGE
# id                                       68539074            39711915
# initial_list_status                             w                   w
# installment                                938.85              272.09
# int_rate                                     7.91               14.99
# loan_amnt                                 30000.0              7850.0
# mort_acc                                      0.0                 1.0
# open_acc                                     19.0                 8.0
# pub_rec                                       0.0                 0.0
# pub_rec_bankruptcies                          0.0                 0.0
# purpose                               credit_card  debt_consolidation
# revol_bal                                 33243.0              6620.0
# revol_util                                   44.1                77.0
# sub_grade                                      A5                  C5
# term                                    36 months           36 months
# title                     Credit card refinancing  Debt consolidation
# total_acc                                    61.0                24.0
# verification_status               Source Verified            Verified
# zip_code                                    606xx               463xx
# last_pymnt_amnt                            941.74             1594.23
# num_actv_rev_tl                               5.0                 5.0
# mo_sin_rcnt_rev_tl_op                        11.0                 2.0
# mo_sin_old_rev_tl_op                        237.0               297.0
# bc_util                                      46.7                73.7
# bc_open_to_buy                            37957.0               947.0
# avg_cur_bal                                5302.0              4954.0
# acc_open_past_24mths                          3.0                 9.0
# charged_off                                 False               False
#
#                                              2                        3
# funded_amnt                            25000.0                  23000.0  \
# addr_state                                  AZ                       CO
# annual_inc                            115000.0                 177000.0
# application_type                    Individual               Individual
# dti                                      23.27                    13.91
# earliest_cr_line                      Dec-2001                 Aug-2001
# emp_length                             9 years                 < 1 year
# emp_title                     VP of Operations         Property Manager
# fico_range_high                          704.0                    704.0
# fico_range_low                           700.0                    700.0
# grade                                        C                        A
# home_ownership                        MORTGAGE                     RENT
# id                                    40919338                 43550224
# initial_list_status                          w                        w
# installment                             573.06                   703.78
# int_rate                                 13.33                     6.39
# loan_amnt                              25000.0                  23000.0
# mort_acc                                   3.0                      2.0
# open_acc                                  12.0                     18.0
# pub_rec                                    0.0                      0.0
# pub_rec_bankruptcies                       0.0                      0.0
# purpose                            credit_card              credit_card
# revol_bal                              41324.0                  23369.0
# revol_util                                62.3                     47.8
# sub_grade                                   C3                       A2
# term                                 60 months                36 months
# title                  Credit card refinancing  Credit card refinancing
# total_acc                                 34.0                     51.0
# verification_status            Source Verified          Source Verified
# zip_code                                 853xx                    805xx
# last_pymnt_amnt                       22209.46                 11497.09
# num_actv_rev_tl                            7.0                      9.0
# mo_sin_rcnt_rev_tl_op                      7.0                     35.0
# mo_sin_old_rev_tl_op                     158.0                    163.0
# bc_util                                   60.1                     70.4
# bc_open_to_buy                         17049.0                   8341.0
# avg_cur_bal                             8770.0                   8395.0
# acc_open_past_24mths                       7.0                      0.0
# charged_off                              False                    False
#
#                                         4
# funded_amnt                       12000.0
# addr_state                             TX
# annual_inc                        98000.0
# application_type               Individual
# dti                                  22.3
# earliest_cr_line                 Sep-2000
# emp_length                      10+ years
# emp_title               HEAVY DUTY DRIVER
# fico_range_high                     699.0
# fico_range_low                      695.0
# grade                                   B
# home_ownership                       RENT
# id                               85518575
# initial_list_status                     w
# installment                        392.81
# int_rate                            10.99
# loan_amnt                         12000.0
# mort_acc                              0.0
# open_acc                             13.0
# pub_rec                               0.0
# pub_rec_bankruptcies                  0.0
# purpose                debt_consolidation
# revol_bal                         10679.0
# revol_util                           57.7
# sub_grade                              B4
# term                            36 months
# title                  Debt consolidation
# total_acc                            18.0
# verification_status              Verified
# zip_code                            770xx
# last_pymnt_amnt                    392.81
# num_actv_rev_tl                       7.0
# mo_sin_rcnt_rev_tl_op                 6.0
# mo_sin_old_rev_tl_op                190.0
# bc_util                              64.3
# bc_open_to_buy                     3316.0
# avg_cur_bal                        6460.0
# acc_open_past_24mths                  7.0
# charged_off                          True

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# Moving forward we will focus on the numeric features only.

# %%
numeric_features = [
    "funded_amnt",
    "last_pymnt_amnt",
    "int_rate",
    "loan_amnt",
    "installment",
    "acc_open_past_24mths",
    "dti",
    "fico_range_low",
    "mort_acc",
]

# %% [markdown]
# ## Creating the `FeatureSelector` Column Transformer

# %% [markdown]
# Creating the customer feature selector which will be the first step in all the pipelines.

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class FeatureSelector(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        return X[self.columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# Next we use `Pipelines` and `ColumnTransformers` to affect preprocessing of our data.

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier

# %%
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler(with_mean=True))  
])

# %%
preprocessor = ColumnTransformer(transformers=[
    ('numerical', numerical_transformer, numeric_features),],
    remainder = 'passthrough',
)

# %% [markdown]
# ## Model Definition and Fitting

# %% [markdown]
# Now, lets' put our preprocessor together with a `RandomForestClassifier` estimator and fit our model.

# %%
model = Pipeline(steps=[
    ('feature_selector', FeatureSelector(numeric_features)),
    ('preprocessor', preprocessor),
    ('random_forest', RandomForestClassifier(n_estimators=50, max_depth=10, n_jobs=-1, random_state=0))
])

# %%
X = df_default.drop(columns=(['charged_off']))
y = df_default['charged_off']

# %%
model.fit(X, y)
# Out:
# Pipeline(steps=[('feature_selector',
#                  FeatureSelector(columns=['funded_amnt', 'last_pymnt_amnt',
#                                           'int_rate', 'loan_amnt',
#                                           'installment', 'acc_open_past_24mths',
#                                           'dti', 'fico_range_low',
#                                           'mort_acc'])),
#                 ('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('numerical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['funded_amnt',
#                                                    'last_pymnt_amnt',
#                                                    'int_rate', 'loan_amnt',
#                                                    'installment',
#                                                    'acc_open_past_24mths',
#                                                    'dti', 'fico_range_low',
#                                                    'mort_acc'])])),
#                 ('random_forest',
#                  RandomForestClassifier(max_depth=10, n_estimators=50,
#                                         n_jobs=-1, random_state=0))])

# %% [markdown]
# As we can see, our model has decent accuracy and predicts a reasonable number of defaults.

# %%
model.score(X, y)
# Out:
# 0.8844236680762895

# %%
model.predict(X).mean()
# Out:
# 0.16917702654506547

# %% [markdown]
# ## Threshold Tuning

# %% [markdown]
# The default threshold of discrimination for **sklearn** classifiers is 0.5.  Sometimes with imbalanced data sets performance can be improve by choosing a different threshold.
#
# We will now search for the optimal threshold.

# %%
# predict probabilities
yhat = model.predict_proba(X)

# %%
# keep probabilities for the positive outcome only
probs = yhat[:, 1]
probs
# Out:
# array([0.17199049, 0.00336728, 0.00094877, ..., 0.58326199, 0.00066442,
#        0.65419674])

# %%
# define thresholds
thresholds = np.arange(0, 1, 0.01)

# %%
# apply threshold to positive probabilities to create inferences
def to_inference(pos_probs, threshold):
	return (pos_probs >= threshold).astype('int')

# %%
from sklearn.metrics import f1_score, accuracy_score
# evaluate each threshold
scores = [accuracy_score(y, to_inference(probs, t)) for t in thresholds]

# %% [markdown]
# It looks like the optimal threshold for our model is 0.47, so fairly close to 0.5.

# %%
# get best threshold
ix = np.argmax(scores)
print('Threshold=%.3f, Accuracy=%.5f' % (thresholds[ix], scores[ix]))
# Out:
# Threshold=0.480, Accuracy=0.88495

# %% [markdown]
# The overall number of defaults is slightly improved with this threshold.

# %%
to_inference(probs, 0.48).mean()
# Out:
# 0.18192201219408638

# %% [markdown]
# ## Saving Fitted Model to Pickle

# %% [markdown]
# Finally, let's save our fitted model to a pickle file.

# %%
import joblib

joblib.dump(model, "pickle/lending_club_model.pkl")
# Out:
# ['pickle/lending_club_model.pkl']
